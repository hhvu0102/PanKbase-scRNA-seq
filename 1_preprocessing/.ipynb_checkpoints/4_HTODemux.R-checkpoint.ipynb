# %% [markdown]
# # How to analyze HTO data

# %% [markdown]
# In our database, we utilized HTO data generated from https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE251912. This documentation has intructi

# %%
library(Matrix)
library(Seurat)
library(ggplot2)
# Out:
# Attaching SeuratObject

# %%
'''
The catalogue numbers from Human Biolegend TotalSeq are A0251-A0257. Please find sequences for all of them below:
A0251 = GTCAACTCTTTAGCG
A0252 = TGATGGCCTATTGGG
A0253 = TTCCGCCTCTCTTTG
A0254 = AGTAAGTTCAGCGTA
A0255 = AAGTATCGTTTCGCA
A0256 = GGTTGCCAGATGTCA
A0257 = TGTCTTTCCTGCCAG

Islet 67:
# islet 67 GEX samples: SRR27326986, SRR27326987
A0251 = 24Hr Untreated
A0252 = 24Hr Untreated
A0253 = 24Hr Untreated
A0254 = 24Hr Untreated
A0255 = 2Hr H2O2
A0256 = 4Hr Cytokines
A0257 = 24Hr Cytokines
 
Islet 116 & Islet 117:
A0251 = 24Hr Untreated
A0252 = 2Hr Cytokines
A0253 = 4Hr Cytokines
A0254 = 16h Cytokines
A0255 = 24Hr Cytokines
A0256 = 2Hr H2O2
 
Islet 150, Islet 162 & Islet 168:
# islet 150 GEX samples: SRR27326996, SRR27326997
# islet 162 GEX samples: SRR27326994, SRR27326995
# islet 168 GEX samples: SRR27326992, SRR27326993
A0251 = 2Hr Thapsigargin
A0252 = 4Hr Thapsigargin
A0253 = 4Hr DMSO
A0254 = 24Hr Untreated
A0255 = 24h DMSO
A0256 = 24h Thapsigargin
'''

# %%
hto_dir = "/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/data/GEO/"
gex_dir = "/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/temp_rds/"

# %%
load_HTO <- function(barcode.path, features.path, matrix.path) {
    mat.htos <- readMM(file = matrix.path)
    feature.names = read.delim(features.path, header = FALSE, stringsAsFactors = FALSE)
    barcode.names = read.delim(barcode.path, header = FALSE, stringsAsFactors = FALSE)
    colnames(mat.htos) = barcode.names$V1
    rownames(mat.htos) = feature.names$V1
    
    return(mat.htos)
}

# %%
load_mm <- function(matrix_file, features_file, barcodes_file) {
    tmp <- as(Matrix::readMM(matrix_file), 'dgCMatrix')
    features <- read.table(features_file, as.is=T, sep='\t', head=F)
    features <- paste0(features$V1, ' (', features$V2, ')')
    barcodes <- read.table(barcodes_file, as.is=T, head=F)[,1]
    dimnames(tmp) <- list(features, barcodes)
    return(tmp)
}


RNA_BARCODES <- paste0(gex_dir, "SRR27326996.barcodes.tsv")
RNA_FEATURES <- paste0(gex_dir, "SRR27326996.features.tsv")
RNA_MTX <- paste0(gex_dir, "SRR27326996.matrix.mtx")

mm <- load_mm(RNA_MTX, RNA_FEATURES, RNA_BARCODES)
rna <- CreateSeuratObject(counts = mm, min.cells=1, min.features=1, assay = "RNA", project='RNA')
rna <- NormalizeData(rna, verbose=F)
rna <- FindVariableFeatures(rna, selection.method='vst', nfeatures=2000, verbose=F)
rna <- ScaleData(rna, verbose=F)
rna <- RunPCA(rna, npcs=200, verbose=F)
rna <- RunUMAP(rna, reduction='pca', dims=1:PCS)
rna <- FindNeighbors(rna, dims = 1:PCS, k.param = 20)
rna <- FindClusters(rna, resolution = RESOLUTION, n.start = 100)

# %% [markdown]
# # Generate singlet files

# %% [markdown]
# ## Islet 150

# %%
# islet 150 GEX samples: SRR27326996, SRR27326997

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_1_umi_count_matrix.mtx.gz --features GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_1_umi_count_genes.tsv.gz --barcodes GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_1_umi_count_barcodes.tsv.gz --rna SRR27326996.rna.rds --prefix Islet150_SRR27326996_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_2_umi_count_matrix.mtx.gz --features GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_2_umi_count_genes.tsv.gz --barcodes GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_2_umi_count_barcodes.tsv.gz --rna SRR27326997.rna.rds --prefix Islet150_SRR27326997_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# ### Islet 150 technical rep 1

# %%
HTO_BC <- paste0(hto_dir, "GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_1_umi_count_barcodes.tsv.gz")
HTO_FEATURE <- paste0(hto_dir, "GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_1_umi_count_genes.tsv.gz")
HTO_MATRIX <- paste0(hto_dir, "GSM7989940_Islet_150_SAMN21845647_Technical_Replicate_1_umi_count_matrix.mtx.gz")

mat.htos <- load_HTO(HTO_BC, HTO_FEATURE, HTO_MATRIX)

rna <- readRDS(paste0(gex_dir, "SRR27326996.rna.rds"))

joint.bcs <- intersect(colnames(mat.htos), colnames(rna))
length(joint.bcs)

# %%
mat.htos[1:5, 1:5]

# %%
rowSums(mat.htos)
mat.htos = mat.htos[rownames(mat.htos) != "unmapped", ]
mat.htos = mat.htos[rowSums(mat.htos) > 0, ]
rowSums(mat.htos)

# %%
# Subset RNA and HTO counts by joint cell barcodes
rna <- rna[, joint.bcs]
mat.htos <- as.matrix(mat.htos[, joint.bcs])

# Confirm that the HTO have the correct names
rownames(mat.htos)

# %%
# Setup Seurat object
islet.hashtag <- CreateSeuratObject(counts = rna@assays$RNA@counts)

islet.hashtag <- NormalizeData(islet.hashtag)
islet.hashtag <- FindVariableFeatures(islet.hashtag, selection.method = "mean.var.plot")
islet.hashtag <- ScaleData(islet.hashtag, features = VariableFeatures(islet.hashtag))

# Add HTO data as a new assay independent from RNA
islet.hashtag[["HTO"]] <- CreateAssayObject(counts = mat.htos)
# Normalize HTO data, here we use centered log-ratio (CLR) transformation
islet.hashtag <- NormalizeData(islet.hashtag, assay = "HTO", normalization.method = "CLR")

islet.hashtag

# %%
islet.hashtag <- HTODemux(islet.hashtag, assay = "HTO", positive.quantile = 0.99)
table(islet.hashtag$HTO_classification.global)
# Group cells based on the max HTO signal
Idents(islet.hashtag) <- "HTO_maxID"

# %%
Idents(islet.hashtag) <- "HTO_classification.global"
options(repr.plot.width = 9, repr.plot.height = 3, repr.plot.res = 300)
VlnPlot(islet.hashtag, features = "nCount_RNA", pt.size = 0.1, log = TRUE)

# %%
# First, we will remove negative cells from the object
islet.hashtag.subset <- subset(islet.hashtag, idents = "Negative", invert = TRUE)

# Calculate a UMAP embedding of the HTO data
DefaultAssay(islet.hashtag.subset) <- "HTO"
islet.hashtag.subset <- ScaleData(islet.hashtag.subset, features = rownames(islet.hashtag.subset),
    verbose = FALSE)
islet.hashtag.subset <- RunPCA(islet.hashtag.subset, features = rownames(islet.hashtag.subset), approx = FALSE)
islet.hashtag.subset <- RunUMAP(islet.hashtag.subset, dims = 1:6)

options(repr.plot.width = 8, repr.plot.height = 7, repr.plot.res = 300)
DimPlot(islet.hashtag.subset)

# %%
ElbowPlot(islet.singlet)

# %%
# Extract the singlets
islet.singlet <- subset(islet.hashtag, idents = "Singlet")

# Select the top 1000 most variable features
islet.singlet <- FindVariableFeatures(islet.singlet, selection.method = "mean.var.plot")

# Scaling RNA data, we only scale the variable features here for efficiency
islet.singlet <- ScaleData(islet.singlet, features = VariableFeatures(islet.singlet))

# Run PCA
islet.singlet <- RunPCA(islet.singlet, features = VariableFeatures(islet.singlet))

# We select the top 10 PCs for clustering and tSNE based on PCElbowPlot
islet.singlet <- FindNeighbors(islet.singlet, reduction = "pca", dims = 1:10)
islet.singlet <- FindClusters(islet.singlet, resolution = 0.6, verbose = FALSE)
islet.singlet <- RunUMAP(islet.singlet, reduction = "pca", dims = 1:10)

# %%
options(repr.plot.width = 8, repr.plot.height = 5, repr.plot.res = 300)
# Projecting singlet identities on UMAP visualization
DimPlot(islet.singlet, group.by = "HTO_classification")

# %%
islet.singlet

# %%
islet.singlet@meta.data

# %% [markdown]
# ## Islet 162

# %%
# islet 162 GEX samples: SRR27326994, SRR27326995

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989941_Islet_162_SAMN25980818_umi_count_matrix.mtx.gz --features GSM7989941_Islet_162_SAMN25980818_umi_count_genes.tsv.gz --barcodes GSM7989941_Islet_162_SAMN25980818_umi_count_barcodes.tsv.gz --rna SRR27326995.rna.rds --prefix Islet162_SRR27326995_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989941_Islet_162_SAMN25980818_umi_count_matrix.mtx.gz --features GSM7989941_Islet_162_SAMN25980818_umi_count_genes.tsv.gz --barcodes GSM7989941_Islet_162_SAMN25980818_umi_count_barcodes.tsv.gz --rna SRR27326994.rna.rds --prefix Islet162_SRR27326994_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# ## Islet 168

# %%
# islet 168 GEX samples: SRR27326992, SRR27326993

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989942_Islet_168_SAMN29494287_Technical_Replicate_1_umi_count_matrix.mtx --features GSM7989942_Islet_168_SAMN29494287_Technical_Replicate_1_umi_count_genes.tsv --barcodes GSM7989942_Islet_168_SAMN29494287_Technical_Replicate_1_umi_count_barcodes.tsv --rna SRR27326992.rna.rds --prefix Islet168_SRR27326992_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989942_Islet_168_SAMN29494287_Technical_Replicate_2_umi_count_matrix.mtx.gz --features GSM7989942_Islet_168_SAMN29494287_Technical_Replicate_2_umi_count_genes.tsv.gz --barcodes GSM7989942_Islet_168_SAMN29494287_Technical_Replicate_2_umi_count_barcodes.tsv.gz --rna SRR27326993.rna.rds --prefix Islet168_SRR27326993_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# ## Islet 67

# %%
# islet 67 GEX samples: SRR27326986, SRR27326987

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989943_Islet_67_SAMN12496804_umi_count_matrix.mtx.gz --features GSM7989943_Islet_67_SAMN12496804_umi_count_genes.tsv.gz --barcodes GSM7989943_Islet_67_SAMN12496804_umi_count_barcodes.tsv.gz --rna SRR27326987.rna.rds --prefix Islet67_SRR27326987_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# Rscript /nfs/turbo/umms-scjp-pank/2_IIDP/scripts/HTODemux.R --matrix GSM7989943_Islet_67_SAMN12496804_umi_count_matrix.mtx.gz --features GSM7989943_Islet_67_SAMN12496804_umi_count_genes.tsv.gz --barcodes GSM7989943_Islet_67_SAMN12496804_umi_count_barcodes.tsv.gz --rna SRR27326986.rna.rds --prefix Islet67_SRR27326986_ --outdir /nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/

# %% [markdown]
# # Merge data

# %%
files <- list.files("/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/", "_singlet.Rds")
files
# Out:
# [1] "Islet150_SRR27326996_singlet.Rds" "Islet150_SRR27326997_singlet.Rds"
# [3] "Islet162_SRR27326994_singlet.Rds" "Islet162_SRR27326995_singlet.Rds"
# [5] "Islet168_SRR27326992_singlet.Rds" "Islet168_SRR27326993_singlet.Rds"
# [7] "Islet67_SRR27326986_singlet.Rds"  "Islet67_SRR27326987_singlet.Rds"

# %%
samples <- unlist(lapply(strsplit(files, "_"), '[', 2))
samples
# Out:
# [1] "SRR27326996" "SRR27326997" "SRR27326994" "SRR27326995" "SRR27326992"
# [6] "SRR27326993" "SRR27326986" "SRR27326987"

# %%
for (i in files) {
    srr <- unlist(lapply(strsplit(i, "_"), '[', 2))
    rna <- readRDS(paste0("/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/", i))
    write.table(Cells(rna), paste0("/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39/emptyDrops/results/pctMTusingBelowEndCliff_pctMtless30_FDR0.005/cellbender_default/", srr, "_passQC_barcodes_demultiplexed.csv"),
               row.names = F, col.names = F, quote = F)
}

# %%
data <- list()
for (i in files[1]) {
    srr <- unlist(lapply(strsplit(i, "_"), '[', 2))
    rna <- readRDS(paste0("/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/", i))
    #rna <- RenameCells(rna, new.names = paste0(srr, "_", rownames(rna@meta.data)))
    #rownames(rna@meta.data) <- paste0(srr, "_", rownames(rna@meta.data))
    rna@meta.data$SRR <- srr
    data[[srr]] <- rna
}

# %%
#Merge Seurat objects for individual samples
merged_data <- merge(data[[samples[1]]], y=data[samples[2:length(samples)]], project='HTO', add.cell.ids=samples)

# %%
merged_data@meta.data
# Out:
#                              orig.ident    nCount_RNA nFeature_RNA nCount_HTO
# SRR27326996_TGATCTTTCGCGTGAC SeuratProject 10580      3767          192
# SRR27326996_TCATTTGGTTGCTCGG SeuratProject 10191      2167          312
# SRR27326996_GCAGGCTCACCAATTG SeuratProject 19283      5438          478
# SRR27326996_TCGGGACTCTTTGGAG SeuratProject 16898      4595          609
# SRR27326996_TCTCACGCATTGACTG SeuratProject 14481      4166          439
# SRR27326996_CTCCGATTCGAACCTA SeuratProject 21830      5644          347
# SRR27326996_CTTACCGTCCAGCACG SeuratProject 15099      4769          333
# SRR27326996_GACCAATGTCGATTTG SeuratProject 17890      4867          657
# SRR27326996_TCGACGGGTACTGTTG SeuratProject 14210      4506          397
# SRR27326996_AACAGGGTCTCGACGG SeuratProject 18770      5316          871
# SRR27326996_TCAGCCTCACTTCATT SeuratProject 12149      4148         1398
# SRR27326996_CTTTCAAAGTGAACAT SeuratProject 14626      3280          368
# SRR27326996_GGGTGAATCGACCTAA SeuratProject 46117      7727          519
# SRR27326996_TCATATCAGTTGTCAC SeuratProject 19297      5501          268
# SRR27326996_TCCGAAAAGTGCCCGT SeuratProject 16473      5021          346
# SRR27326996_TTGCATTTCGGTAGGA SeuratProject  9252      3512          642
# SRR27326996_GTAGAAAGTCACGCTG SeuratProject 51408      6865         1225
# SRR27326996_CGGGTGTTCTTCGCTG SeuratProject 18694      5395          671
# SRR27326996_ATTTCTGTCTGGAGAG SeuratProject 33830      6067          763
# SRR27326996_GCGTGCATCTTTCCGG SeuratProject 10884      3962          319
# SRR27326996_AGGTGTTCAACGGCTC SeuratProject 24017      6116          434
# SRR27326996_TTACGTTAGGGTTAGC SeuratProject 27320      6190          792
# SRR27326996_CTATCCGCACCATATG SeuratProject 21436      5624         1096
# SRR27326996_GCGTTTCCATCATCTT SeuratProject 17585      5419          263
# SRR27326996_TTTGGAGTCCGTGGTG SeuratProject 10900      4210          286
# SRR27326996_AGCTTCCAGTGCAAAT SeuratProject 18865      4912          311
# SRR27326996_ATATCCTAGGTATCTC SeuratProject 20815      4473          282
# SRR27326996_TGTACAGCATGCCATA SeuratProject 18057      4647          275
# SRR27326996_GTAATGCAGGTCGTCC SeuratProject 11986      3922          520
# SRR27326996_CTATCTAGTAGACGGT SeuratProject 28944      5776          489
# ⋮                            ⋮             ⋮          ⋮            ⋮
# SRR27326987_GGGTGTCCAGCTTCGG SeuratProject 42168      6296          98
# SRR27326987_GAAGCCCGTAGTGATA SeuratProject 17642      5544          41
# SRR27326987_TTCCTAACAATTGCCA SeuratProject 15146      4414         296
# SRR27326987_TTACCGCTCACCTTAT SeuratProject 40303      7254         140
# SRR27326987_CCGTGAGTCCATATGG SeuratProject 46581      6569         336
# SRR27326987_CAGTTAGAGGATTCCT SeuratProject 40220      6299          43
# SRR27326987_TTGAGTGCAAGACCGA SeuratProject 23162      4997          50
# SRR27326987_CCTGTTGGTAGTCACT SeuratProject 26879      6118         255
# SRR27326987_CAGATACCAGAGGTTG SeuratProject 36794      6147         193
# SRR27326987_TGTGATGTCTAGCAAC SeuratProject 11818      4724         352
# SRR27326987_TGCTTGCTCTGGACCG SeuratProject 18502      5242          31
# SRR27326987_TGAGGTTCAACGGCCT SeuratProject 18296      2631          41
# SRR27326987_TGCATCCCACAAATAG SeuratProject 47821      6815         297
# SRR27326987_TGCATCCAGTGTCATC SeuratProject 38931      6533          49
# SRR27326987_TACACCCAGTGACCTT SeuratProject 54782      7947          56
# SRR27326987_TTGAACGTCTGACCCT SeuratProject 24899      4410         539
# SRR27326987_AGGGTTTGTGTAGTGG SeuratProject 28393      5830          50
# SRR27326987_TTAGTCTTCAGATTGC SeuratProject 15633      4626         221
# SRR27326987_TCCACCAGTATCGCTA SeuratProject 53749      7667         954
# SRR27326987_TTGGTTTGTCTGCGCA SeuratProject 19282      4215          25
# SRR27326987_CTCAACCGTTCGGCCA SeuratProject 13209      4382         548
# SRR27326987_TTTCACATCCATTGTT SeuratProject 11401      3904          90
# SRR27326987_TTGTTTGGTTCTAACG SeuratProject 20516      4249          47
# SRR27326987_TTGTTTGTCCTTCTTC SeuratProject 22858      5109          18
# SRR27326987_CATACTTCACTCCCTA SeuratProject 15580      4678          34
# SRR27326987_GGGACAATCAACGAGG SeuratProject 12625      4047          19
# SRR27326987_GGTTCTCTCCTTCAGC SeuratProject 16629      4808          61
# SRR27326987_GAGGGATCACAAATGA SeuratProject 12175      3618          46
# SRR27326987_TACCTGCAGGGAGGCA SeuratProject 26919      5420         167
# SRR27326987_CTATCCGCACCACTGG SeuratProject 30706      7024          27
#                              nFeature_HTO HTO_maxID
# SRR27326996_TGATCTTTCGCGTGAC 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TCATTTGGTTGCTCGG 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_GCAGGCTCACCAATTG 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TCGGGACTCTTTGGAG 6            0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_TCTCACGCATTGACTG 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_CTCCGATTCGAACCTA 6            0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_CTTACCGTCCAGCACG 6            0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_GACCAATGTCGATTTG 6            0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_TCGACGGGTACTGTTG 6            0251-HHTO-01-GTCAACTCTTTAGCG
# SRR27326996_AACAGGGTCTCGACGG 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_TCAGCCTCACTTCATT 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_CTTTCAAAGTGAACAT 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_GGGTGAATCGACCTAA 6            0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_TCATATCAGTTGTCAC 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TCCGAAAAGTGCCCGT 6            0255-HHTO-05-AAGTATCGTTTCGCA
# SRR27326996_TTGCATTTCGGTAGGA 6            0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_GTAGAAAGTCACGCTG 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_CGGGTGTTCTTCGCTG 6            0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_ATTTCTGTCTGGAGAG 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_GCGTGCATCTTTCCGG 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_AGGTGTTCAACGGCTC 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TTACGTTAGGGTTAGC 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_CTATCCGCACCATATG 6            0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_GCGTTTCCATCATCTT 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TTTGGAGTCCGTGGTG 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_AGCTTCCAGTGCAAAT 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_ATATCCTAGGTATCTC 6            0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_TGTACAGCATGCCATA 6            0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_GTAATGCAGGTCGTCC 6            0255-HHTO-05-AAGTATCGTTTCGCA
# SRR27326996_CTATCTAGTAGACGGT 6            0254-HHTO-04-AGTAAGTTCAGCGTA
# ⋮                            ⋮            ⋮
# SRR27326987_GGGTGTCCAGCTTCGG 6            HHTO1-GTCAACTCTTTAGCG
# SRR27326987_GAAGCCCGTAGTGATA 5            HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TTCCTAACAATTGCCA 6            HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_TTACCGCTCACCTTAT 5            HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_CCGTGAGTCCATATGG 6            HHTO1-GTCAACTCTTTAGCG
# SRR27326987_CAGTTAGAGGATTCCT 7            HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TTGAGTGCAAGACCGA 7            HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_CCTGTTGGTAGTCACT 6            HHTO6-GGTTGCCAGATGTCA
# SRR27326987_CAGATACCAGAGGTTG 5            HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_TGTGATGTCTAGCAAC 5            HHTO5-AAGTATCGTTTCGCA
# SRR27326987_TGCTTGCTCTGGACCG 6            HHTO6-GGTTGCCAGATGTCA
# SRR27326987_TGAGGTTCAACGGCCT 7            HHTO5-AAGTATCGTTTCGCA
# SRR27326987_TGCATCCCACAAATAG 7            HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TGCATCCAGTGTCATC 5            HHTO6-GGTTGCCAGATGTCA
# SRR27326987_TACACCCAGTGACCTT 7            HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TTGAACGTCTGACCCT 7            HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_AGGGTTTGTGTAGTGG 6            HHTO5-AAGTATCGTTTCGCA
# SRR27326987_TTAGTCTTCAGATTGC 6            HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_TCCACCAGTATCGCTA 5            HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TTGGTTTGTCTGCGCA 7            HHTO1-GTCAACTCTTTAGCG
# SRR27326987_CTCAACCGTTCGGCCA 6            HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TTTCACATCCATTGTT 7            HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TTGTTTGGTTCTAACG 7            HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_TTGTTTGTCCTTCTTC 5            HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_CATACTTCACTCCCTA 5            HHTO5-AAGTATCGTTTCGCA
# SRR27326987_GGGACAATCAACGAGG 4            HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_GGTTCTCTCCTTCAGC 6            HHTO5-AAGTATCGTTTCGCA
# SRR27326987_GAGGGATCACAAATGA 6            HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TACCTGCAGGGAGGCA 6            HHTO2-TGATGGCCTATTGGG
# SRR27326987_CTATCCGCACCACTGG 5            HHTO1-GTCAACTCTTTAGCG
#                              HTO_secondID                 HTO_margin
# SRR27326996_TGATCTTTCGCGTGAC 0255-HHTO-05-AAGTATCGTTTCGCA 1.281194
# SRR27326996_TCATTTGGTTGCTCGG 0255-HHTO-05-AAGTATCGTTTCGCA 1.208670
# SRR27326996_GCAGGCTCACCAATTG 0254-HHTO-04-AGTAAGTTCAGCGTA 1.830183
# SRR27326996_TCGGGACTCTTTGGAG 0251-HHTO-01-GTCAACTCTTTAGCG 3.808796
# SRR27326996_TCTCACGCATTGACTG 0253-HHTO-03-TTCCGCCTCTCTTTG 1.797123
# SRR27326996_CTCCGATTCGAACCTA 0253-HHTO-03-TTCCGCCTCTCTTTG 3.155060
# SRR27326996_CTTACCGTCCAGCACG 0255-HHTO-05-AAGTATCGTTTCGCA 1.729341
# SRR27326996_GACCAATGTCGATTTG 0253-HHTO-03-TTCCGCCTCTCTTTG 3.678370
# SRR27326996_TCGACGGGTACTGTTG 0254-HHTO-04-AGTAAGTTCAGCGTA 2.564421
# SRR27326996_AACAGGGTCTCGACGG 0254-HHTO-04-AGTAAGTTCAGCGTA 2.406239
# SRR27326996_TCAGCCTCACTTCATT 0251-HHTO-01-GTCAACTCTTTAGCG 2.897613
# SRR27326996_CTTTCAAAGTGAACAT 0252-HHTO-02-TGATGGCCTATTGGG 1.947900
# SRR27326996_GGGTGAATCGACCTAA 0252-HHTO-02-TGATGGCCTATTGGG 3.371053
# SRR27326996_TCATATCAGTTGTCAC 0251-HHTO-01-GTCAACTCTTTAGCG 1.560972
# SRR27326996_TCCGAAAAGTGCCCGT 0254-HHTO-04-AGTAAGTTCAGCGTA 2.569020
# SRR27326996_TTGCATTTCGGTAGGA 0254-HHTO-04-AGTAAGTTCAGCGTA 2.969067
# SRR27326996_GTAGAAAGTCACGCTG 0251-HHTO-01-GTCAACTCTTTAGCG 2.242385
# SRR27326996_CGGGTGTTCTTCGCTG 0254-HHTO-04-AGTAAGTTCAGCGTA 2.652239
# SRR27326996_ATTTCTGTCTGGAGAG 0251-HHTO-01-GTCAACTCTTTAGCG 2.545186
# SRR27326996_GCGTGCATCTTTCCGG 0255-HHTO-05-AAGTATCGTTTCGCA 1.552326
# SRR27326996_AGGTGTTCAACGGCTC 0254-HHTO-04-AGTAAGTTCAGCGTA 2.224265
# SRR27326996_TTACGTTAGGGTTAGC 0254-HHTO-04-AGTAAGTTCAGCGTA 2.176324
# SRR27326996_CTATCCGCACCATATG 0255-HHTO-05-AAGTATCGTTTCGCA 3.241701
# SRR27326996_GCGTTTCCATCATCTT 0252-HHTO-02-TGATGGCCTATTGGG 1.255386
# SRR27326996_TTTGGAGTCCGTGGTG 0254-HHTO-04-AGTAAGTTCAGCGTA 1.388299
# SRR27326996_AGCTTCCAGTGCAAAT 0254-HHTO-04-AGTAAGTTCAGCGTA 1.174294
# SRR27326996_ATATCCTAGGTATCTC 0254-HHTO-04-AGTAAGTTCAGCGTA 1.522381
# SRR27326996_TGTACAGCATGCCATA 0252-HHTO-02-TGATGGCCTATTGGG 1.640645
# SRR27326996_GTAATGCAGGTCGTCC 0254-HHTO-04-AGTAAGTTCAGCGTA 2.914167
# SRR27326996_CTATCTAGTAGACGGT 0252-HHTO-02-TGATGGCCTATTGGG 3.494540
# ⋮                            ⋮                            ⋮
# SRR27326987_GGGTGTCCAGCTTCGG HHTO7-TGTCTTTCCTGCCAG        2.5819316
# SRR27326987_GAAGCCCGTAGTGATA HHTO5-AAGTATCGTTTCGCA        1.3733193
# SRR27326987_TTCCTAACAATTGCCA HHTO2-TGATGGCCTATTGGG        3.2178022
# SRR27326987_TTACCGCTCACCTTAT HHTO6-GGTTGCCAGATGTCA        3.0716475
# SRR27326987_CCGTGAGTCCATATGG HHTO2-TGATGGCCTATTGGG        3.9335175
# SRR27326987_CAGTTAGAGGATTCCT HHTO4-AGTAAGTTCAGCGTA        1.5598115
# SRR27326987_TTGAGTGCAAGACCGA HHTO1-GTCAACTCTTTAGCG        1.8576066
# SRR27326987_CCTGTTGGTAGTCACT HHTO5-AAGTATCGTTTCGCA        2.5889312
# SRR27326987_CAGATACCAGAGGTTG HHTO6-GGTTGCCAGATGTCA        3.4126523
# SRR27326987_TGTGATGTCTAGCAAC HHTO1-GTCAACTCTTTAGCG        3.0480665
# SRR27326987_TGCTTGCTCTGGACCG HHTO2-TGATGGCCTATTGGG        1.6492790
# SRR27326987_TGAGGTTCAACGGCCT HHTO2-TGATGGCCTATTGGG        0.9274351
# SRR27326987_TGCATCCCACAAATAG HHTO2-TGATGGCCTATTGGG        4.2820641
# SRR27326987_TGCATCCAGTGTCATC HHTO3-TTCCGCCTCTCTTTG        1.6167863
# SRR27326987_TACACCCAGTGACCTT HHTO4-AGTAAGTTCAGCGTA        0.7781314
# SRR27326987_TTGAACGTCTGACCCT HHTO6-GGTTGCCAGATGTCA        3.1241368
# SRR27326987_AGGGTTTGTGTAGTGG HHTO3-TTCCGCCTCTCTTTG        1.3314345
# SRR27326987_TTAGTCTTCAGATTGC HHTO5-AAGTATCGTTTCGCA        3.4204973
# SRR27326987_TCCACCAGTATCGCTA HHTO4-AGTAAGTTCAGCGTA        3.7044922
# SRR27326987_TTGGTTTGTCTGCGCA HHTO2-TGATGGCCTATTGGG        0.8612790
# SRR27326987_CTCAACCGTTCGGCCA HHTO4-AGTAAGTTCAGCGTA        3.1483815
# SRR27326987_TTTCACATCCATTGTT HHTO7-TGTCTTTCCTGCCAG        2.9571282
# SRR27326987_TTGTTTGGTTCTAACG HHTO3-TTCCGCCTCTCTTTG        0.5083612
# SRR27326987_TTGTTTGTCCTTCTTC HHTO5-AAGTATCGTTTCGCA        1.0619380
# SRR27326987_CATACTTCACTCCCTA HHTO3-TTCCGCCTCTCTTTG        1.0507682
# SRR27326987_GGGACAATCAACGAGG HHTO7-TGTCTTTCCTGCCAG        1.0183152
# SRR27326987_GGTTCTCTCCTTCAGC HHTO3-TTCCGCCTCTCTTTG        1.5225676
# SRR27326987_GAGGGATCACAAATGA HHTO6-GGTTGCCAGATGTCA        0.8588865
# SRR27326987_TACCTGCAGGGAGGCA HHTO7-TGTCTTTCCTGCCAG        3.3312652
# SRR27326987_CTATCCGCACCACTGG HHTO3-TTCCGCCTCTCTTTG        1.3771800
#                              HTO_classification
# SRR27326996_TGATCTTTCGCGTGAC 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TCATTTGGTTGCTCGG 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_GCAGGCTCACCAATTG 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TCGGGACTCTTTGGAG 0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_TCTCACGCATTGACTG 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_CTCCGATTCGAACCTA 0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_CTTACCGTCCAGCACG 0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_GACCAATGTCGATTTG 0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_TCGACGGGTACTGTTG 0251-HHTO-01-GTCAACTCTTTAGCG
# SRR27326996_AACAGGGTCTCGACGG 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_TCAGCCTCACTTCATT 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_CTTTCAAAGTGAACAT 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_GGGTGAATCGACCTAA 0254-HHTO-04-AGTAAGTTCAGCGTA
# SRR27326996_TCATATCAGTTGTCAC 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TCCGAAAAGTGCCCGT 0255-HHTO-05-AAGTATCGTTTCGCA
# SRR27326996_TTGCATTTCGGTAGGA 0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_GTAGAAAGTCACGCTG 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_CGGGTGTTCTTCGCTG 0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_ATTTCTGTCTGGAGAG 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_GCGTGCATCTTTCCGG 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_AGGTGTTCAACGGCTC 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TTACGTTAGGGTTAGC 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_CTATCCGCACCATATG 0256-HHTO-06-GGTTGCCAGATGTCA
# SRR27326996_GCGTTTCCATCATCTT 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_TTTGGAGTCCGTGGTG 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_AGCTTCCAGTGCAAAT 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_ATATCCTAGGTATCTC 0252-HHTO-02-TGATGGCCTATTGGG
# SRR27326996_TGTACAGCATGCCATA 0253-HHTO-03-TTCCGCCTCTCTTTG
# SRR27326996_GTAATGCAGGTCGTCC 0255-HHTO-05-AAGTATCGTTTCGCA
# SRR27326996_CTATCTAGTAGACGGT 0254-HHTO-04-AGTAAGTTCAGCGTA
# ⋮                            ⋮
# SRR27326987_GGGTGTCCAGCTTCGG HHTO1-GTCAACTCTTTAGCG
# SRR27326987_GAAGCCCGTAGTGATA HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TTCCTAACAATTGCCA HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_TTACCGCTCACCTTAT HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_CCGTGAGTCCATATGG HHTO1-GTCAACTCTTTAGCG
# SRR27326987_CAGTTAGAGGATTCCT HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TTGAGTGCAAGACCGA HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_CCTGTTGGTAGTCACT HHTO6-GGTTGCCAGATGTCA
# SRR27326987_CAGATACCAGAGGTTG HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_TGTGATGTCTAGCAAC HHTO5-AAGTATCGTTTCGCA
# SRR27326987_TGCTTGCTCTGGACCG HHTO6-GGTTGCCAGATGTCA
# SRR27326987_TGAGGTTCAACGGCCT HHTO5-AAGTATCGTTTCGCA
# SRR27326987_TGCATCCCACAAATAG HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TGCATCCAGTGTCATC HHTO6-GGTTGCCAGATGTCA
# SRR27326987_TACACCCAGTGACCTT HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TTGAACGTCTGACCCT HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_AGGGTTTGTGTAGTGG HHTO5-AAGTATCGTTTCGCA
# SRR27326987_TTAGTCTTCAGATTGC HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_TCCACCAGTATCGCTA HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TTGGTTTGTCTGCGCA HHTO1-GTCAACTCTTTAGCG
# SRR27326987_CTCAACCGTTCGGCCA HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TTTCACATCCATTGTT HHTO1-GTCAACTCTTTAGCG
# SRR27326987_TTGTTTGGTTCTAACG HHTO4-AGTAAGTTCAGCGTA
# SRR27326987_TTGTTTGTCCTTCTTC HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_CATACTTCACTCCCTA HHTO5-AAGTATCGTTTCGCA
# SRR27326987_GGGACAATCAACGAGG HHTO3-TTCCGCCTCTCTTTG
# SRR27326987_GGTTCTCTCCTTCAGC HHTO5-AAGTATCGTTTCGCA
# SRR27326987_GAGGGATCACAAATGA HHTO7-TGTCTTTCCTGCCAG
# SRR27326987_TACCTGCAGGGAGGCA HHTO2-TGATGGCCTATTGGG
# SRR27326987_CTATCCGCACCACTGG HHTO1-GTCAACTCTTTAGCG
#                              HTO_classification.global
# SRR27326996_TGATCTTTCGCGTGAC Singlet
# SRR27326996_TCATTTGGTTGCTCGG Singlet
# SRR27326996_GCAGGCTCACCAATTG Singlet
# SRR27326996_TCGGGACTCTTTGGAG Singlet
# SRR27326996_TCTCACGCATTGACTG Singlet
# SRR27326996_CTCCGATTCGAACCTA Singlet
# SRR27326996_CTTACCGTCCAGCACG Singlet
# SRR27326996_GACCAATGTCGATTTG Singlet
# SRR27326996_TCGACGGGTACTGTTG Singlet
# SRR27326996_AACAGGGTCTCGACGG Singlet
# SRR27326996_TCAGCCTCACTTCATT Singlet
# SRR27326996_CTTTCAAAGTGAACAT Singlet
# SRR27326996_GGGTGAATCGACCTAA Singlet
# SRR27326996_TCATATCAGTTGTCAC Singlet
# SRR27326996_TCCGAAAAGTGCCCGT Singlet
# SRR27326996_TTGCATTTCGGTAGGA Singlet
# SRR27326996_GTAGAAAGTCACGCTG Singlet
# SRR27326996_CGGGTGTTCTTCGCTG Singlet
# SRR27326996_ATTTCTGTCTGGAGAG Singlet
# SRR27326996_GCGTGCATCTTTCCGG Singlet
# SRR27326996_AGGTGTTCAACGGCTC Singlet
# SRR27326996_TTACGTTAGGGTTAGC Singlet
# SRR27326996_CTATCCGCACCATATG Singlet
# SRR27326996_GCGTTTCCATCATCTT Singlet
# SRR27326996_TTTGGAGTCCGTGGTG Singlet
# SRR27326996_AGCTTCCAGTGCAAAT Singlet
# SRR27326996_ATATCCTAGGTATCTC Singlet
# SRR27326996_TGTACAGCATGCCATA Singlet
# SRR27326996_GTAATGCAGGTCGTCC Singlet
# SRR27326996_CTATCTAGTAGACGGT Singlet
# ⋮                            ⋮
# SRR27326987_GGGTGTCCAGCTTCGG Singlet
# SRR27326987_GAAGCCCGTAGTGATA Singlet
# SRR27326987_TTCCTAACAATTGCCA Singlet
# SRR27326987_TTACCGCTCACCTTAT Singlet
# SRR27326987_CCGTGAGTCCATATGG Singlet
# SRR27326987_CAGTTAGAGGATTCCT Singlet
# SRR27326987_TTGAGTGCAAGACCGA Singlet
# SRR27326987_CCTGTTGGTAGTCACT Singlet
# SRR27326987_CAGATACCAGAGGTTG Singlet
# SRR27326987_TGTGATGTCTAGCAAC Singlet
# SRR27326987_TGCTTGCTCTGGACCG Singlet
# SRR27326987_TGAGGTTCAACGGCCT Singlet
# SRR27326987_TGCATCCCACAAATAG Singlet
# SRR27326987_TGCATCCAGTGTCATC Singlet
# SRR27326987_TACACCCAGTGACCTT Singlet
# SRR27326987_TTGAACGTCTGACCCT Singlet
# SRR27326987_AGGGTTTGTGTAGTGG Singlet
# SRR27326987_TTAGTCTTCAGATTGC Singlet
# SRR27326987_TCCACCAGTATCGCTA Singlet
# SRR27326987_TTGGTTTGTCTGCGCA Singlet
# SRR27326987_CTCAACCGTTCGGCCA Singlet
# SRR27326987_TTTCACATCCATTGTT Singlet
# SRR27326987_TTGTTTGGTTCTAACG Singlet
# SRR27326987_TTGTTTGTCCTTCTTC Singlet
# SRR27326987_CATACTTCACTCCCTA Singlet
# SRR27326987_GGGACAATCAACGAGG Singlet
# SRR27326987_GGTTCTCTCCTTCAGC Singlet
# SRR27326987_GAGGGATCACAAATGA Singlet
# SRR27326987_TACCTGCAGGGAGGCA Singlet
# SRR27326987_CTATCCGCACCACTGG Singlet
#                              hash.ID                      RNA_snn_res.0.6
# SRR27326996_TGATCTTTCGCGTGAC 0253-HHTO-03-TTCCGCCTCTCTTTG 1
# SRR27326996_TCATTTGGTTGCTCGG 0252-HHTO-02-TGATGGCCTATTGGG 6
# SRR27326996_GCAGGCTCACCAATTG 0253-HHTO-03-TTCCGCCTCTCTTTG 2
# SRR27326996_TCGGGACTCTTTGGAG 0254-HHTO-04-AGTAAGTTCAGCGTA 0
# SRR27326996_TCTCACGCATTGACTG 0252-HHTO-02-TGATGGCCTATTGGG 0
# SRR27326996_CTCCGATTCGAACCTA 0254-HHTO-04-AGTAAGTTCAGCGTA 0
# SRR27326996_CTTACCGTCCAGCACG 0256-HHTO-06-GGTTGCCAGATGTCA 1
# SRR27326996_GACCAATGTCGATTTG 0254-HHTO-04-AGTAAGTTCAGCGTA 2
# SRR27326996_TCGACGGGTACTGTTG 0251-HHTO-01-GTCAACTCTTTAGCG 10
# SRR27326996_AACAGGGTCTCGACGG 0252-HHTO-02-TGATGGCCTATTGGG 0
# SRR27326996_TCAGCCTCACTTCATT 0252-HHTO-02-TGATGGCCTATTGGG 15
# SRR27326996_CTTTCAAAGTGAACAT 0253-HHTO-03-TTCCGCCTCTCTTTG 4
# SRR27326996_GGGTGAATCGACCTAA 0254-HHTO-04-AGTAAGTTCAGCGTA 11
# SRR27326996_TCATATCAGTTGTCAC 0253-HHTO-03-TTCCGCCTCTCTTTG 1
# SRR27326996_TCCGAAAAGTGCCCGT 0255-HHTO-05-AAGTATCGTTTCGCA 4
# SRR27326996_TTGCATTTCGGTAGGA 0256-HHTO-06-GGTTGCCAGATGTCA 15
# SRR27326996_GTAGAAAGTCACGCTG 0252-HHTO-02-TGATGGCCTATTGGG 0
# SRR27326996_CGGGTGTTCTTCGCTG 0256-HHTO-06-GGTTGCCAGATGTCA 0
# SRR27326996_ATTTCTGTCTGGAGAG 0252-HHTO-02-TGATGGCCTATTGGG 4
# SRR27326996_GCGTGCATCTTTCCGG 0253-HHTO-03-TTCCGCCTCTCTTTG 4
# SRR27326996_AGGTGTTCAACGGCTC 0253-HHTO-03-TTCCGCCTCTCTTTG 1
# SRR27326996_TTACGTTAGGGTTAGC 0253-HHTO-03-TTCCGCCTCTCTTTG 2
# SRR27326996_CTATCCGCACCATATG 0256-HHTO-06-GGTTGCCAGATGTCA 4
# SRR27326996_GCGTTTCCATCATCTT 0253-HHTO-03-TTCCGCCTCTCTTTG 1
# SRR27326996_TTTGGAGTCCGTGGTG 0252-HHTO-02-TGATGGCCTATTGGG 16
# SRR27326996_AGCTTCCAGTGCAAAT 0253-HHTO-03-TTCCGCCTCTCTTTG 4
# SRR27326996_ATATCCTAGGTATCTC 0252-HHTO-02-TGATGGCCTATTGGG 3
# SRR27326996_TGTACAGCATGCCATA 0253-HHTO-03-TTCCGCCTCTCTTTG 2
# SRR27326996_GTAATGCAGGTCGTCC 0255-HHTO-05-AAGTATCGTTTCGCA 1
# SRR27326996_CTATCTAGTAGACGGT 0254-HHTO-04-AGTAAGTTCAGCGTA 2
# ⋮                            ⋮                            ⋮
# SRR27326987_GGGTGTCCAGCTTCGG HHTO1-GTCAACTCTTTAGCG        1
# SRR27326987_GAAGCCCGTAGTGATA HHTO1-GTCAACTCTTTAGCG        6
# SRR27326987_TTCCTAACAATTGCCA HHTO4-AGTAAGTTCAGCGTA        10
# SRR27326987_TTACCGCTCACCTTAT HHTO4-AGTAAGTTCAGCGTA        5
# SRR27326987_CCGTGAGTCCATATGG HHTO1-GTCAACTCTTTAGCG        5
# SRR27326987_CAGTTAGAGGATTCCT HHTO1-GTCAACTCTTTAGCG        1
# SRR27326987_TTGAGTGCAAGACCGA HHTO3-TTCCGCCTCTCTTTG        5
# SRR27326987_CCTGTTGGTAGTCACT HHTO6-GGTTGCCAGATGTCA        2
# SRR27326987_CAGATACCAGAGGTTG HHTO3-TTCCGCCTCTCTTTG        1
# SRR27326987_TGTGATGTCTAGCAAC HHTO5-AAGTATCGTTTCGCA        9
# SRR27326987_TGCTTGCTCTGGACCG HHTO6-GGTTGCCAGATGTCA        2
# SRR27326987_TGAGGTTCAACGGCCT HHTO5-AAGTATCGTTTCGCA        7
# SRR27326987_TGCATCCCACAAATAG HHTO1-GTCAACTCTTTAGCG        5
# SRR27326987_TGCATCCAGTGTCATC HHTO6-GGTTGCCAGATGTCA        3
# SRR27326987_TACACCCAGTGACCTT HHTO7-TGTCTTTCCTGCCAG        12
# SRR27326987_TTGAACGTCTGACCCT HHTO7-TGTCTTTCCTGCCAG        4
# SRR27326987_AGGGTTTGTGTAGTGG HHTO5-AAGTATCGTTTCGCA        5
# SRR27326987_TTAGTCTTCAGATTGC HHTO4-AGTAAGTTCAGCGTA        0
# SRR27326987_TCCACCAGTATCGCTA HHTO7-TGTCTTTCCTGCCAG        4
# SRR27326987_TTGGTTTGTCTGCGCA HHTO1-GTCAACTCTTTAGCG        1
# SRR27326987_CTCAACCGTTCGGCCA HHTO7-TGTCTTTCCTGCCAG        2
# SRR27326987_TTTCACATCCATTGTT HHTO1-GTCAACTCTTTAGCG        0
# SRR27326987_TTGTTTGGTTCTAACG HHTO4-AGTAAGTTCAGCGTA        1
# SRR27326987_TTGTTTGTCCTTCTTC HHTO3-TTCCGCCTCTCTTTG        5
# SRR27326987_CATACTTCACTCCCTA HHTO5-AAGTATCGTTTCGCA        9
# SRR27326987_GGGACAATCAACGAGG HHTO3-TTCCGCCTCTCTTTG        0
# SRR27326987_GGTTCTCTCCTTCAGC HHTO5-AAGTATCGTTTCGCA        1
# SRR27326987_GAGGGATCACAAATGA HHTO7-TGTCTTTCCTGCCAG        2
# SRR27326987_TACCTGCAGGGAGGCA HHTO2-TGATGGCCTATTGGG        5
# SRR27326987_CTATCCGCACCACTGG HHTO1-GTCAACTCTTTAGCG        0
#                              seurat_clusters SRR
# SRR27326996_TGATCTTTCGCGTGAC 1               SRR27326996
# SRR27326996_TCATTTGGTTGCTCGG 6               SRR27326996
# SRR27326996_GCAGGCTCACCAATTG 2               SRR27326996
# SRR27326996_TCGGGACTCTTTGGAG 0               SRR27326996
# SRR27326996_TCTCACGCATTGACTG 0               SRR27326996
# SRR27326996_CTCCGATTCGAACCTA 0               SRR27326996
# SRR27326996_CTTACCGTCCAGCACG 1               SRR27326996
# SRR27326996_GACCAATGTCGATTTG 2               SRR27326996
# SRR27326996_TCGACGGGTACTGTTG 10              SRR27326996
# SRR27326996_AACAGGGTCTCGACGG 0               SRR27326996
# SRR27326996_TCAGCCTCACTTCATT 15              SRR27326996
# SRR27326996_CTTTCAAAGTGAACAT 4               SRR27326996
# SRR27326996_GGGTGAATCGACCTAA 11              SRR27326996
# SRR27326996_TCATATCAGTTGTCAC 1               SRR27326996
# SRR27326996_TCCGAAAAGTGCCCGT 4               SRR27326996
# SRR27326996_TTGCATTTCGGTAGGA 15              SRR27326996
# SRR27326996_GTAGAAAGTCACGCTG 0               SRR27326996
# SRR27326996_CGGGTGTTCTTCGCTG 0               SRR27326996
# SRR27326996_ATTTCTGTCTGGAGAG 4               SRR27326996
# SRR27326996_GCGTGCATCTTTCCGG 4               SRR27326996
# SRR27326996_AGGTGTTCAACGGCTC 1               SRR27326996
# SRR27326996_TTACGTTAGGGTTAGC 2               SRR27326996
# SRR27326996_CTATCCGCACCATATG 4               SRR27326996
# SRR27326996_GCGTTTCCATCATCTT 1               SRR27326996
# SRR27326996_TTTGGAGTCCGTGGTG 16              SRR27326996
# SRR27326996_AGCTTCCAGTGCAAAT 4               SRR27326996
# SRR27326996_ATATCCTAGGTATCTC 3               SRR27326996
# SRR27326996_TGTACAGCATGCCATA 2               SRR27326996
# SRR27326996_GTAATGCAGGTCGTCC 1               SRR27326996
# SRR27326996_CTATCTAGTAGACGGT 2               SRR27326996
# ⋮                            ⋮               ⋮
# SRR27326987_GGGTGTCCAGCTTCGG 1               SRR27326987
# SRR27326987_GAAGCCCGTAGTGATA 6               SRR27326987
# SRR27326987_TTCCTAACAATTGCCA 10              SRR27326987
# SRR27326987_TTACCGCTCACCTTAT 5               SRR27326987
# SRR27326987_CCGTGAGTCCATATGG 5               SRR27326987
# SRR27326987_CAGTTAGAGGATTCCT 1               SRR27326987
# SRR27326987_TTGAGTGCAAGACCGA 5               SRR27326987
# SRR27326987_CCTGTTGGTAGTCACT 2               SRR27326987
# SRR27326987_CAGATACCAGAGGTTG 1               SRR27326987
# SRR27326987_TGTGATGTCTAGCAAC 9               SRR27326987
# SRR27326987_TGCTTGCTCTGGACCG 2               SRR27326987
# SRR27326987_TGAGGTTCAACGGCCT 7               SRR27326987
# SRR27326987_TGCATCCCACAAATAG 5               SRR27326987
# SRR27326987_TGCATCCAGTGTCATC 3               SRR27326987
# SRR27326987_TACACCCAGTGACCTT 12              SRR27326987
# SRR27326987_TTGAACGTCTGACCCT 4               SRR27326987
# SRR27326987_AGGGTTTGTGTAGTGG 5               SRR27326987
# SRR27326987_TTAGTCTTCAGATTGC 0               SRR27326987
# SRR27326987_TCCACCAGTATCGCTA 4               SRR27326987
# SRR27326987_TTGGTTTGTCTGCGCA 1               SRR27326987
# SRR27326987_CTCAACCGTTCGGCCA 2               SRR27326987
# SRR27326987_TTTCACATCCATTGTT 0               SRR27326987
# SRR27326987_TTGTTTGGTTCTAACG 1               SRR27326987
# SRR27326987_TTGTTTGTCCTTCTTC 5               SRR27326987
# SRR27326987_CATACTTCACTCCCTA 9               SRR27326987
# SRR27326987_GGGACAATCAACGAGG 0               SRR27326987
# SRR27326987_GGTTCTCTCCTTCAGC 1               SRR27326987
# SRR27326987_GAGGGATCACAAATGA 2               SRR27326987
# SRR27326987_TACCTGCAGGGAGGCA 5               SRR27326987
# SRR27326987_CTATCCGCACCACTGG 0               SRR27326987

# %%
saveRDS(merged_data, "/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/merged_HTO.Rds")

# %%
merged_data <- readRDS("/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/merged_HTO.Rds")

# %%
hto_bc <- data.frame(id = c(paste0("A025", seq(1, 7))),
                    HTO_seq = c("GTCAACTCTTTAGCG", "TGATGGCCTATTGGG", "TTCCGCCTCTCTTTG", 
                                "AGTAAGTTCAGCGTA", "AAGTATCGTTTCGCA", "GGTTGCCAGATGTCA", "TGTCTTTCCTGCCAG"))
hto_bc
# Out:
#   id    HTO_seq
# 1 A0251 GTCAACTCTTTAGCG
# 2 A0252 TGATGGCCTATTGGG
# 3 A0253 TTCCGCCTCTCTTTG
# 4 A0254 AGTAAGTTCAGCGTA
# 5 A0255 AAGTATCGTTTCGCA
# 6 A0256 GGTTGCCAGATGTCA
# 7 A0257 TGTCTTTCCTGCCAG

# %%
df <- merged_data@meta.data[, c("HTO_classification", "SRR")]
df$barcode <- unlist(lapply(strsplit(rownames(df), '_', fixed = TRUE), '[', 2))
df$HTO_seq <- sub(".*\\-", "", df$HTO_classification)

tail(df)
# Out:
#                              HTO_classification    SRR         barcode
# SRR27326987_CATACTTCACTCCCTA HHTO5-AAGTATCGTTTCGCA SRR27326987 CATACTTCACTCCCTA
# SRR27326987_GGGACAATCAACGAGG HHTO3-TTCCGCCTCTCTTTG SRR27326987 GGGACAATCAACGAGG
# SRR27326987_GGTTCTCTCCTTCAGC HHTO5-AAGTATCGTTTCGCA SRR27326987 GGTTCTCTCCTTCAGC
# SRR27326987_GAGGGATCACAAATGA HHTO7-TGTCTTTCCTGCCAG SRR27326987 GAGGGATCACAAATGA
# SRR27326987_TACCTGCAGGGAGGCA HHTO2-TGATGGCCTATTGGG SRR27326987 TACCTGCAGGGAGGCA
# SRR27326987_CTATCCGCACCACTGG HHTO1-GTCAACTCTTTAGCG SRR27326987 CTATCCGCACCACTGG
#                              HTO_seq
# SRR27326987_CATACTTCACTCCCTA AAGTATCGTTTCGCA
# SRR27326987_GGGACAATCAACGAGG TTCCGCCTCTCTTTG
# SRR27326987_GGTTCTCTCCTTCAGC AAGTATCGTTTCGCA
# SRR27326987_GAGGGATCACAAATGA TGTCTTTCCTGCCAG
# SRR27326987_TACCTGCAGGGAGGCA TGATGGCCTATTGGG
# SRR27326987_CTATCCGCACCACTGG GTCAACTCTTTAGCG

# %%
#Islet 67:
# islet 67 GEX samples: SRR27326986, SRR27326987
#A0251 = 24Hr Untreated
#A0252 = 24Hr Untreated
#A0253 = 24Hr Untreated
#A0254 = 24Hr Untreated
#A0255 = 2Hr H2O2
#A0256 = 4Hr Cytokines
#A0257 = 24Hr Cytokines

SRR27326986 <- data.frame(SRR = rep("SRR27326986", 7),
                        id = paste0("A025", seq(1, 7)),
                        Treatment = c(rep("24Hr_Untreated", 4),
                                     "2Hr_H2O2", "4Hr_Cytokines", "24Hr_Cytokines"))
SRR27326987 <- data.frame(SRR = rep("SRR27326987", 7),
                        id = paste0("A025", seq(1, 7)),
                        Treatment = c(rep("24Hr_Untreated", 4),
                                     "2Hr_H2O2", "4Hr_Cytokines", "24Hr_Cytokines"))
tmp <- rbind(SRR27326986, SRR27326987)

# %%
#Islet 150, Islet 162 & Islet 168:
# islet 150 GEX samples: SRR27326996, SRR27326997
# islet 162 GEX samples: SRR27326994, SRR27326995
# islet 168 GEX samples: SRR27326992, SRR27326993
#A0251 = 2Hr Thapsigargin
#A0252 = 4Hr Thapsigargin
#A0253 = 4Hr DMSO
#A0254 = 24Hr Untreated
#A0255 = 24h DMSO
#A0256 = 24h Thapsigargin

tmp2 <- data.frame(SRR = rep(c("SRR27326996", "SRR27326997", "SRR27326994", "SRR27326995", "SRR27326992", "SRR27326993"), each = 6),
                   id = rep(paste0("A025", seq(1, 6)), 6),
                   Treatment = rep(c("2Hr_Thapsigargin", "4Hr_Thapsigargin", "4Hr_DMSO", 
                                     "24Hr_Untreated", "24h_DMSO", "24h_Thapsigargin"), 6))
tmp2
# Out:
#    SRR         id    Treatment
# 1  SRR27326996 A0251 2Hr_Thapsigargin
# 2  SRR27326996 A0252 4Hr_Thapsigargin
# 3  SRR27326996 A0253 4Hr_DMSO
# 4  SRR27326996 A0254 24Hr_Untreated
# 5  SRR27326996 A0255 24h_DMSO
# 6  SRR27326996 A0256 24h_Thapsigargin
# 7  SRR27326997 A0251 2Hr_Thapsigargin
# 8  SRR27326997 A0252 4Hr_Thapsigargin
# 9  SRR27326997 A0253 4Hr_DMSO
# 10 SRR27326997 A0254 24Hr_Untreated
# 11 SRR27326997 A0255 24h_DMSO
# 12 SRR27326997 A0256 24h_Thapsigargin
# 13 SRR27326994 A0251 2Hr_Thapsigargin
# 14 SRR27326994 A0252 4Hr_Thapsigargin
# 15 SRR27326994 A0253 4Hr_DMSO
# 16 SRR27326994 A0254 24Hr_Untreated
# 17 SRR27326994 A0255 24h_DMSO
# 18 SRR27326994 A0256 24h_Thapsigargin
# 19 SRR27326995 A0251 2Hr_Thapsigargin
# 20 SRR27326995 A0252 4Hr_Thapsigargin
# 21 SRR27326995 A0253 4Hr_DMSO
# 22 SRR27326995 A0254 24Hr_Untreated
# 23 SRR27326995 A0255 24h_DMSO
# 24 SRR27326995 A0256 24h_Thapsigargin
# 25 SRR27326992 A0251 2Hr_Thapsigargin
# 26 SRR27326992 A0252 4Hr_Thapsigargin
# 27 SRR27326992 A0253 4Hr_DMSO
# 28 SRR27326992 A0254 24Hr_Untreated
# 29 SRR27326992 A0255 24h_DMSO
# 30 SRR27326992 A0256 24h_Thapsigargin
# 31 SRR27326993 A0251 2Hr_Thapsigargin
# 32 SRR27326993 A0252 4Hr_Thapsigargin
# 33 SRR27326993 A0253 4Hr_DMSO
# 34 SRR27326993 A0254 24Hr_Untreated
# 35 SRR27326993 A0255 24h_DMSO
# 36 SRR27326993 A0256 24h_Thapsigargin

# %%
map <- rbind(tmp, tmp2)
map <- inner_join(map, hto_bc)
map
# Out:
# Joining with `by = join_by(id)`
#    SRR         id    Treatment        HTO_seq
# 1  SRR27326986 A0251 24Hr_Untreated   GTCAACTCTTTAGCG
# 2  SRR27326986 A0252 24Hr_Untreated   TGATGGCCTATTGGG
# 3  SRR27326986 A0253 24Hr_Untreated   TTCCGCCTCTCTTTG
# 4  SRR27326986 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 5  SRR27326986 A0255 2Hr_H2O2         AAGTATCGTTTCGCA
# 6  SRR27326986 A0256 4Hr_Cytokines    GGTTGCCAGATGTCA
# 7  SRR27326986 A0257 24Hr_Cytokines   TGTCTTTCCTGCCAG
# 8  SRR27326987 A0251 24Hr_Untreated   GTCAACTCTTTAGCG
# 9  SRR27326987 A0252 24Hr_Untreated   TGATGGCCTATTGGG
# 10 SRR27326987 A0253 24Hr_Untreated   TTCCGCCTCTCTTTG
# 11 SRR27326987 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 12 SRR27326987 A0255 2Hr_H2O2         AAGTATCGTTTCGCA
# 13 SRR27326987 A0256 4Hr_Cytokines    GGTTGCCAGATGTCA
# 14 SRR27326987 A0257 24Hr_Cytokines   TGTCTTTCCTGCCAG
# 15 SRR27326996 A0251 2Hr_Thapsigargin GTCAACTCTTTAGCG
# 16 SRR27326996 A0252 4Hr_Thapsigargin TGATGGCCTATTGGG
# 17 SRR27326996 A0253 4Hr_DMSO         TTCCGCCTCTCTTTG
# 18 SRR27326996 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 19 SRR27326996 A0255 24h_DMSO         AAGTATCGTTTCGCA
# 20 SRR27326996 A0256 24h_Thapsigargin GGTTGCCAGATGTCA
# 21 SRR27326997 A0251 2Hr_Thapsigargin GTCAACTCTTTAGCG
# 22 SRR27326997 A0252 4Hr_Thapsigargin TGATGGCCTATTGGG
# 23 SRR27326997 A0253 4Hr_DMSO         TTCCGCCTCTCTTTG
# 24 SRR27326997 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 25 SRR27326997 A0255 24h_DMSO         AAGTATCGTTTCGCA
# 26 SRR27326997 A0256 24h_Thapsigargin GGTTGCCAGATGTCA
# 27 SRR27326994 A0251 2Hr_Thapsigargin GTCAACTCTTTAGCG
# 28 SRR27326994 A0252 4Hr_Thapsigargin TGATGGCCTATTGGG
# 29 SRR27326994 A0253 4Hr_DMSO         TTCCGCCTCTCTTTG
# 30 SRR27326994 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 31 SRR27326994 A0255 24h_DMSO         AAGTATCGTTTCGCA
# 32 SRR27326994 A0256 24h_Thapsigargin GGTTGCCAGATGTCA
# 33 SRR27326995 A0251 2Hr_Thapsigargin GTCAACTCTTTAGCG
# 34 SRR27326995 A0252 4Hr_Thapsigargin TGATGGCCTATTGGG
# 35 SRR27326995 A0253 4Hr_DMSO         TTCCGCCTCTCTTTG
# 36 SRR27326995 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 37 SRR27326995 A0255 24h_DMSO         AAGTATCGTTTCGCA
# 38 SRR27326995 A0256 24h_Thapsigargin GGTTGCCAGATGTCA
# 39 SRR27326992 A0251 2Hr_Thapsigargin GTCAACTCTTTAGCG
# 40 SRR27326992 A0252 4Hr_Thapsigargin TGATGGCCTATTGGG
# 41 SRR27326992 A0253 4Hr_DMSO         TTCCGCCTCTCTTTG
# 42 SRR27326992 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 43 SRR27326992 A0255 24h_DMSO         AAGTATCGTTTCGCA
# 44 SRR27326992 A0256 24h_Thapsigargin GGTTGCCAGATGTCA
# 45 SRR27326993 A0251 2Hr_Thapsigargin GTCAACTCTTTAGCG
# 46 SRR27326993 A0252 4Hr_Thapsigargin TGATGGCCTATTGGG
# 47 SRR27326993 A0253 4Hr_DMSO         TTCCGCCTCTCTTTG
# 48 SRR27326993 A0254 24Hr_Untreated   AGTAAGTTCAGCGTA
# 49 SRR27326993 A0255 24h_DMSO         AAGTATCGTTTCGCA
# 50 SRR27326993 A0256 24h_Thapsigargin GGTTGCCAGATGTCA

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
dim(df)
df <- inner_join(df, map[, c("SRR", "Treatment", "HTO_seq")])
dim(df)
# Out:
# [1] 41294     4
# Joining with `by = join_by(SRR, HTO_seq)`
# [1] 41294     5

# %%
df
# Out:
#       HTO_classification           SRR         barcode          HTO_seq
# 1     0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 TGATCTTTCGCGTGAC TTCCGCCTCTCTTTG
# 2     0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 TCATTTGGTTGCTCGG TGATGGCCTATTGGG
# 3     0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 GCAGGCTCACCAATTG TTCCGCCTCTCTTTG
# 4     0254-HHTO-04-AGTAAGTTCAGCGTA SRR27326996 TCGGGACTCTTTGGAG AGTAAGTTCAGCGTA
# 5     0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 TCTCACGCATTGACTG TGATGGCCTATTGGG
# 6     0254-HHTO-04-AGTAAGTTCAGCGTA SRR27326996 CTCCGATTCGAACCTA AGTAAGTTCAGCGTA
# 7     0256-HHTO-06-GGTTGCCAGATGTCA SRR27326996 CTTACCGTCCAGCACG GGTTGCCAGATGTCA
# 8     0254-HHTO-04-AGTAAGTTCAGCGTA SRR27326996 GACCAATGTCGATTTG AGTAAGTTCAGCGTA
# 9     0251-HHTO-01-GTCAACTCTTTAGCG SRR27326996 TCGACGGGTACTGTTG GTCAACTCTTTAGCG
# 10    0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 AACAGGGTCTCGACGG TGATGGCCTATTGGG
# 11    0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 TCAGCCTCACTTCATT TGATGGCCTATTGGG
# 12    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 CTTTCAAAGTGAACAT TTCCGCCTCTCTTTG
# 13    0254-HHTO-04-AGTAAGTTCAGCGTA SRR27326996 GGGTGAATCGACCTAA AGTAAGTTCAGCGTA
# 14    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 TCATATCAGTTGTCAC TTCCGCCTCTCTTTG
# 15    0255-HHTO-05-AAGTATCGTTTCGCA SRR27326996 TCCGAAAAGTGCCCGT AAGTATCGTTTCGCA
# 16    0256-HHTO-06-GGTTGCCAGATGTCA SRR27326996 TTGCATTTCGGTAGGA GGTTGCCAGATGTCA
# 17    0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 GTAGAAAGTCACGCTG TGATGGCCTATTGGG
# 18    0256-HHTO-06-GGTTGCCAGATGTCA SRR27326996 CGGGTGTTCTTCGCTG GGTTGCCAGATGTCA
# 19    0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 ATTTCTGTCTGGAGAG TGATGGCCTATTGGG
# 20    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 GCGTGCATCTTTCCGG TTCCGCCTCTCTTTG
# 21    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 AGGTGTTCAACGGCTC TTCCGCCTCTCTTTG
# 22    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 TTACGTTAGGGTTAGC TTCCGCCTCTCTTTG
# 23    0256-HHTO-06-GGTTGCCAGATGTCA SRR27326996 CTATCCGCACCATATG GGTTGCCAGATGTCA
# 24    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 GCGTTTCCATCATCTT TTCCGCCTCTCTTTG
# 25    0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 TTTGGAGTCCGTGGTG TGATGGCCTATTGGG
# 26    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 AGCTTCCAGTGCAAAT TTCCGCCTCTCTTTG
# 27    0252-HHTO-02-TGATGGCCTATTGGG SRR27326996 ATATCCTAGGTATCTC TGATGGCCTATTGGG
# 28    0253-HHTO-03-TTCCGCCTCTCTTTG SRR27326996 TGTACAGCATGCCATA TTCCGCCTCTCTTTG
# 29    0255-HHTO-05-AAGTATCGTTTCGCA SRR27326996 GTAATGCAGGTCGTCC AAGTATCGTTTCGCA
# 30    0254-HHTO-04-AGTAAGTTCAGCGTA SRR27326996 CTATCTAGTAGACGGT AGTAAGTTCAGCGTA
# ⋮     ⋮                            ⋮           ⋮                ⋮
# 41265 HHTO1-GTCAACTCTTTAGCG        SRR27326987 GGGTGTCCAGCTTCGG GTCAACTCTTTAGCG
# 41266 HHTO1-GTCAACTCTTTAGCG        SRR27326987 GAAGCCCGTAGTGATA GTCAACTCTTTAGCG
# 41267 HHTO4-AGTAAGTTCAGCGTA        SRR27326987 TTCCTAACAATTGCCA AGTAAGTTCAGCGTA
# 41268 HHTO4-AGTAAGTTCAGCGTA        SRR27326987 TTACCGCTCACCTTAT AGTAAGTTCAGCGTA
# 41269 HHTO1-GTCAACTCTTTAGCG        SRR27326987 CCGTGAGTCCATATGG GTCAACTCTTTAGCG
# 41270 HHTO1-GTCAACTCTTTAGCG        SRR27326987 CAGTTAGAGGATTCCT GTCAACTCTTTAGCG
# 41271 HHTO3-TTCCGCCTCTCTTTG        SRR27326987 TTGAGTGCAAGACCGA TTCCGCCTCTCTTTG
# 41272 HHTO6-GGTTGCCAGATGTCA        SRR27326987 CCTGTTGGTAGTCACT GGTTGCCAGATGTCA
# 41273 HHTO3-TTCCGCCTCTCTTTG        SRR27326987 CAGATACCAGAGGTTG TTCCGCCTCTCTTTG
# 41274 HHTO5-AAGTATCGTTTCGCA        SRR27326987 TGTGATGTCTAGCAAC AAGTATCGTTTCGCA
# 41275 HHTO6-GGTTGCCAGATGTCA        SRR27326987 TGCTTGCTCTGGACCG GGTTGCCAGATGTCA
# 41276 HHTO5-AAGTATCGTTTCGCA        SRR27326987 TGAGGTTCAACGGCCT AAGTATCGTTTCGCA
# 41277 HHTO1-GTCAACTCTTTAGCG        SRR27326987 TGCATCCCACAAATAG GTCAACTCTTTAGCG
# 41278 HHTO6-GGTTGCCAGATGTCA        SRR27326987 TGCATCCAGTGTCATC GGTTGCCAGATGTCA
# 41279 HHTO7-TGTCTTTCCTGCCAG        SRR27326987 TACACCCAGTGACCTT TGTCTTTCCTGCCAG
# 41280 HHTO7-TGTCTTTCCTGCCAG        SRR27326987 TTGAACGTCTGACCCT TGTCTTTCCTGCCAG
# 41281 HHTO5-AAGTATCGTTTCGCA        SRR27326987 AGGGTTTGTGTAGTGG AAGTATCGTTTCGCA
# 41282 HHTO4-AGTAAGTTCAGCGTA        SRR27326987 TTAGTCTTCAGATTGC AGTAAGTTCAGCGTA
# 41283 HHTO7-TGTCTTTCCTGCCAG        SRR27326987 TCCACCAGTATCGCTA TGTCTTTCCTGCCAG
# 41284 HHTO1-GTCAACTCTTTAGCG        SRR27326987 TTGGTTTGTCTGCGCA GTCAACTCTTTAGCG
# 41285 HHTO7-TGTCTTTCCTGCCAG        SRR27326987 CTCAACCGTTCGGCCA TGTCTTTCCTGCCAG
# 41286 HHTO1-GTCAACTCTTTAGCG        SRR27326987 TTTCACATCCATTGTT GTCAACTCTTTAGCG
# 41287 HHTO4-AGTAAGTTCAGCGTA        SRR27326987 TTGTTTGGTTCTAACG AGTAAGTTCAGCGTA
# 41288 HHTO3-TTCCGCCTCTCTTTG        SRR27326987 TTGTTTGTCCTTCTTC TTCCGCCTCTCTTTG
# 41289 HHTO5-AAGTATCGTTTCGCA        SRR27326987 CATACTTCACTCCCTA AAGTATCGTTTCGCA
# 41290 HHTO3-TTCCGCCTCTCTTTG        SRR27326987 GGGACAATCAACGAGG TTCCGCCTCTCTTTG
# 41291 HHTO5-AAGTATCGTTTCGCA        SRR27326987 GGTTCTCTCCTTCAGC AAGTATCGTTTCGCA
# 41292 HHTO7-TGTCTTTCCTGCCAG        SRR27326987 GAGGGATCACAAATGA TGTCTTTCCTGCCAG
# 41293 HHTO2-TGATGGCCTATTGGG        SRR27326987 TACCTGCAGGGAGGCA TGATGGCCTATTGGG
# 41294 HHTO1-GTCAACTCTTTAGCG        SRR27326987 CTATCCGCACCACTGG GTCAACTCTTTAGCG
#       Treatment
# 1     4Hr_DMSO
# 2     4Hr_Thapsigargin
# 3     4Hr_DMSO
# 4     24Hr_Untreated
# 5     4Hr_Thapsigargin
# 6     24Hr_Untreated
# 7     24h_Thapsigargin
# 8     24Hr_Untreated
# 9     2Hr_Thapsigargin
# 10    4Hr_Thapsigargin
# 11    4Hr_Thapsigargin
# 12    4Hr_DMSO
# 13    24Hr_Untreated
# 14    4Hr_DMSO
# 15    24h_DMSO
# 16    24h_Thapsigargin
# 17    4Hr_Thapsigargin
# 18    24h_Thapsigargin
# 19    4Hr_Thapsigargin
# 20    4Hr_DMSO
# 21    4Hr_DMSO
# 22    4Hr_DMSO
# 23    24h_Thapsigargin
# 24    4Hr_DMSO
# 25    4Hr_Thapsigargin
# 26    4Hr_DMSO
# 27    4Hr_Thapsigargin
# 28    4Hr_DMSO
# 29    24h_DMSO
# 30    24Hr_Untreated
# ⋮     ⋮
# 41265 24Hr_Untreated
# 41266 24Hr_Untreated
# 41267 24Hr_Untreated
# 41268 24Hr_Untreated
# 41269 24Hr_Untreated
# 41270 24Hr_Untreated
# 41271 24Hr_Untreated
# 41272 4Hr_Cytokines
# 41273 24Hr_Untreated
# 41274 2Hr_H2O2
# 41275 4Hr_Cytokines
# 41276 2Hr_H2O2
# 41277 24Hr_Untreated
# 41278 4Hr_Cytokines
# 41279 24Hr_Cytokines
# 41280 24Hr_Cytokines
# 41281 2Hr_H2O2
# 41282 24Hr_Untreated
# 41283 24Hr_Cytokines
# 41284 24Hr_Untreated
# 41285 24Hr_Cytokines
# 41286 24Hr_Untreated
# 41287 24Hr_Untreated
# 41288 24Hr_Untreated
# 41289 2Hr_H2O2
# 41290 24Hr_Untreated
# 41291 2Hr_H2O2
# 41292 24Hr_Cytokines
# 41293 24Hr_Untreated
# 41294 24Hr_Untreated

# %%
write.table(df, "/nfs/turbo/umms-scjp-pank/2_IIDP/results/gencode_v39_private/GSE251912/results/singlets/HTO_barcode_maps.txt",
           sep = "\t", quote = F, row.names = F)
